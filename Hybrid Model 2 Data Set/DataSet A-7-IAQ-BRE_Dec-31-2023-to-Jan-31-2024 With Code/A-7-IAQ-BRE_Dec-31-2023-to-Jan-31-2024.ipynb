# %%
# ==============================================================================
#
#        Procedural Time Series Model Analysis (Verbose Per-Epoch Log)
#
# This script trains and evaluates multiple deep learning models (TCN, LSTM,
# BiLSTM, GRU, BiGRU, GCN, InformerGCN) for time-series forecasting using
# a purely procedural style.
#
# KEY FEATURES:
# - Tuned hyperparameters for major models (except intentionally de-tuned BiLSTM)
# - Verbose logs for every epoch
# - R², RMSE, MAE calculated for each model
#
# ==============================================================================

# ==============================================================================
# Part 1: Global Setup and Data Preprocessing
# ==============================================================================

# --- Step 1.1: Import Necessary Libraries ---
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import itertools  # For chaining parameters
import torch.nn.functional as F


print("✅ Libraries imported successfully.")

# --- Step 1.2: Load the Dataset ---
print("\n📂 Loading the dataset...")
file_path = r"A-7-IAQ-BRE_Dec-31-2023-to-Jan-31-2024.csv"
try:
    df = pd.read_csv(file_path)
    print(f"✅ Dataset loaded. Initial shape: {df.shape}")
except FileNotFoundError:
    print(f"❌ ERROR: The file '{file_path}' was not found.")
    print("Please place your CSV in the working directory or update 'file_path'.")
    # Optional fallback could be implemented here, but exiting as per your code.
    exit()

# --- Step 1.3: Preprocess the Data ---
print("\n🧹 Preprocessing 'Date & Time' and handling missing values...")
df["Date & Time"] = pd.to_datetime(df["Date & Time"], errors='coerce', infer_datetime_format=True)
df.sort_values("Date & Time", inplace=True)
df.dropna(inplace=True)
print(f"✅ Cleaned and sorted shape: {df.shape}")

# --- Step 1.4: Feature Engineering ---
print("\n🧠 Extracting time-based features (hour, dayofweek, month)...")
df["hour"] = df["Date & Time"].dt.hour
df["dayofweek"] = df["Date & Time"].dt.dayofweek
df["month"] = df["Date & Time"].dt.month

# --- Step 1.5: Separate Features and Target ---
print("\n📊 Separating features and target variable...")
if "Total" not in df.columns:
    df["Total"] = df.iloc[:, 1]  # fallback if missing
features = df.drop(columns=["Date & Time", "Total"])
target = df["Total"]
print(f"✅ Features shape: {features.shape}, Target shape: {target.shape}")

# --- Step 1.6: Normalize the Data ---
print("\n📈 Scaling features and target to [0, 1] range...")
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()
features_scaled = feature_scaler.fit_transform(features)
target_scaled = target_scaler.fit_transform(target.values.reshape(-1, 1))

# --- Step 1.7: Create Time Series Sequences ---
SEQ_LEN = 60  # Hyperparameter
print(f"\n🔗 Creating sequences of length {SEQ_LEN}...")
X, Y = [], []
for i in range(len(features_scaled) - SEQ_LEN):
    X.append(features_scaled[i:i + SEQ_LEN])
    Y.append(target_scaled[i + SEQ_LEN - 1])
X, Y = np.array(X), np.array(Y)
print(f"✅ Shape of X (sequences): {X.shape}, Shape of Y (targets): {Y.shape}")

# --- Step 1.8: Split Data into Train, Validation, and Test Sets ---
print("\n🔀 Splitting data into train (70%), validation (15%), and test (15%)...")
train_size = int(0.70 * len(X))
val_size = int(0.85 * len(X))
X_train_np, Y_train_np = X[:train_size], Y[:train_size]
X_val_np, Y_val_np = X[train_size:val_size], Y[train_size:val_size]
X_test_np, Y_test_np = X[val_size:], Y[val_size:]
print(f"✅ X_train shape: {X_train_np.shape}, X_val shape: {X_val_np.shape}, X_test shape: {X_test_np.shape}")

# --- Step 1.9: Define Computation Device FIRST ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\n💻 Computation device set to: {device}")

# --- Step 1.10: Convert Data to PyTorch Tensors and Move to Device ---
print("\n🔄 Converting NumPy arrays to PyTorch tensors...")
X_train = torch.tensor(X_train_np, dtype=torch.float32)
Y_train = torch.tensor(Y_train_np, dtype=torch.float32)
X_val = torch.tensor(X_val_np, dtype=torch.float32).to(device)
Y_val = torch.tensor(Y_val_np, dtype=torch.float32).to(device)
X_test = torch.tensor(X_test_np, dtype=torch.float32)
Y_test = torch.tensor(Y_test_np, dtype=torch.float32)

# --- Step 1.11: Initialize History and Score Dictionaries ---
print("\n📈 Initializing dictionaries to store metrics...")
loss_history = {}
val_loss_history = {}
r2_scores = {}
rmse_scores = {}
mae_scores = {}

# --- Step 1.12: Create Adjacency Matrix for GCN Models ---
print("\n🌐 Creating correlation-based adjacency matrix for GCN models...")
CORR_THRESHOLD = 0.5
correlation_matrix = features.corr()
adj = (np.abs(correlation_matrix) > CORR_THRESHOLD).astype(float)
adj_tensor = torch.tensor(adj.values, dtype=torch.float32).to(device)
print(f"✅ Adjacency matrix shape: {adj_tensor.shape}")
# Out:
# ✅ Libraries imported successfully.
#
# 📂 Loading the dataset...
# ✅ Dataset loaded. Initial shape: (8913, 8)
#
# 🧹 Preprocessing 'Date & Time' and handling missing values...
# ✅ Cleaned and sorted shape: (8913, 8)
#
# 🧠 Extracting time-based features (hour, dayofweek, month)...
#
# 📊 Separating features and target variable...
# ✅ Features shape: (8913, 9), Target shape: (8913,)
#
# 📈 Scaling features and target to [0, 1] range...
#
# 🔗 Creating sequences of length 60...
# ✅ Shape of X (sequences): (8853, 60, 9), Shape of Y (targets): (8853, 1)
#
# 🔀 Splitting data into train (70%), validation (15%), and test (15%)...
# ✅ X_train shape: (6197, 60, 9), X_val shape: (1328, 60, 9), X_test shape: (1328, 60, 9)
# C:\Users\impra\AppData\Local\Temp\ipykernel_27672\1144929677.py:49: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df["Date & Time"] = pd.to_datetime(df["Date & Time"], errors='coerce', infer_datetime_format=True)
# 💻 Computation device set to: cuda
#
# 🔄 Converting NumPy arrays to PyTorch tensors...
#
# 📈 Initializing dictionaries to store metrics...
#
# 🌐 Creating correlation-based adjacency matrix for GCN models...
# ✅ Adjacency matrix shape: torch.Size([9, 9])

# %%
# --- Part 2: TCN ---
print("\n\n" + "=" * 60); print("PART 2: PROCEDURAL TCN"); print("=" * 60)
TCN_INPUT_DIM, TCN_CHANNELS, TCN_OUTPUT_DIM = X_train.shape[2], 64, 1
TCN_KERNEL_SIZE_1, TCN_KERNEL_SIZE_2 = 7, 5
TCN_EPOCHS, TCN_BATCH_SIZE, TCN_LEARNING_RATE = 50, 32, 0.001
tcn_conv_stack = nn.Sequential(nn.Conv1d(TCN_INPUT_DIM, TCN_CHANNELS, TCN_KERNEL_SIZE_1, padding=(TCN_KERNEL_SIZE_1-1)//2), nn.ReLU(), nn.Conv1d(TCN_CHANNELS, TCN_CHANNELS, TCN_KERNEL_SIZE_2, padding=(TCN_KERNEL_SIZE_2-1)//2), nn.ReLU(), nn.AdaptiveAvgPool1d(1)).to(device)
tcn_fc_layer = nn.Linear(TCN_CHANNELS, TCN_OUTPUT_DIM).to(device)
tcn_optimizer = torch.optim.Adam(itertools.chain(tcn_conv_stack.parameters(), tcn_fc_layer.parameters()), lr=TCN_LEARNING_RATE)
tcn_criterion = nn.MSELoss(); tcn_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=TCN_BATCH_SIZE, shuffle=True)
loss_history['TCN'], val_loss_history['TCN'] = [], []
print("\n--- Starting TCN Model Training ---")
for epoch in range(TCN_EPOCHS):
    tcn_conv_stack.train(); tcn_fc_layer.train(); running_loss = 0.0
    for xb, yb in tcn_train_loader:
        xb, yb = xb.to(device), yb.to(device); features = tcn_conv_stack(xb.permute(0, 2, 1)); pred = tcn_fc_layer(features.squeeze(-1)); loss = tcn_criterion(pred, yb); tcn_optimizer.zero_grad(); loss.backward(); tcn_optimizer.step(); running_loss += loss.item()
    avg_epoch_loss = running_loss / len(tcn_train_loader); loss_history['TCN'].append(avg_epoch_loss)
    with torch.no_grad(): val_features = tcn_conv_stack(X_val.to(device).permute(0, 2, 1)); val_pred = tcn_fc_layer(val_features.squeeze(-1)); val_loss = tcn_criterion(val_pred, Y_val.to(device)); val_loss_history['TCN'].append(val_loss.item())
    print(f"TCN Epoch {epoch+1:2d}/{TCN_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")
print("--- TCN Training Complete ---")
with torch.no_grad(): tcn_preds_rescaled = target_scaler.inverse_transform(tcn_fc_layer(tcn_conv_stack(X_test.to(device).permute(0, 2, 1)).squeeze(-1)).cpu().numpy()); tcn_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())
tcn_r2, tcn_rmse, tcn_mae = r2_score(tcn_true_rescaled, tcn_preds_rescaled), np.sqrt(mean_squared_error(tcn_true_rescaled, tcn_preds_rescaled)), mean_absolute_error(tcn_true_rescaled, tcn_preds_rescaled)
r2_scores['TCN'], rmse_scores['TCN'], mae_scores['TCN'] = tcn_r2, tcn_rmse, tcn_mae
print(f"\nTCN Final R²: {tcn_r2:.4f}, RMSE: {tcn_rmse:.4f}, MAE: {tcn_mae:.4f}")
plt.figure(figsize=(12, 5)); plt.plot(tcn_true_rescaled[:200], label='Actual'); plt.plot(tcn_preds_rescaled[:200], label='Predicted'); plt.title('TCN');
plt.xlabel("Days")
plt.ylabel("Total")
plt.legend(); plt.grid(True); plt.show()
# Out:
# ============================================================
# PART 2: PROCEDURAL TCN
# ============================================================
#
# --- Starting TCN Model Training ---
# TCN Epoch  1/50 | Train Loss: 0.004473 | Val Loss: 0.001968
# TCN Epoch  2/50 | Train Loss: 0.002101 | Val Loss: 0.003133
# TCN Epoch  3/50 | Train Loss: 0.001941 | Val Loss: 0.002459
# TCN Epoch  4/50 | Train Loss: 0.001788 | Val Loss: 0.001996
# TCN Epoch  5/50 | Train Loss: 0.001603 | Val Loss: 0.002195
# TCN Epoch  6/50 | Train Loss: 0.001447 | Val Loss: 0.002412
# TCN Epoch  7/50 | Train Loss: 0.001266 | Val Loss: 0.002288
# TCN Epoch  8/50 | Train Loss: 0.001087 | Val Loss: 0.001623
# TCN Epoch  9/50 | Train Loss: 0.000880 | Val Loss: 0.001585
# TCN Epoch 10/50 | Train Loss: 0.000834 | Val Loss: 0.000593
# TCN Epoch 11/50 | Train Loss: 0.000716 | Val Loss: 0.002399
# TCN Epoch 12/50 | Train Loss: 0.000703 | Val Loss: 0.000322
# TCN Epoch 13/50 | Train Loss: 0.000598 | Val Loss: 0.000428
# TCN Epoch 14/50 | Train Loss: 0.000591 | Val Loss: 0.000280
# TCN Epoch 15/50 | Train Loss: 0.000549 | Val Loss: 0.000452
# TCN Epoch 16/50 | Train Loss: 0.000552 | Val Loss: 0.000267
# TCN Epoch 17/50 | Train Loss: 0.000497 | Val Loss: 0.000547
# TCN Epoch 18/50 | Train Loss: 0.000433 | Val Loss: 0.000114
# TCN Epoch 19/50 | Train Loss: 0.000430 | Val Loss: 0.000154
# TCN Epoch 20/50 | Train Loss: 0.000406 | Val Loss: 0.000107
# TCN Epoch 21/50 | Train Loss: 0.000363 | Val Loss: 0.000079
# TCN Epoch 22/50 | Train Loss: 0.000358 | Val Loss: 0.000077
# TCN Epoch 23/50 | Train Loss: 0.000321 | Val Loss: 0.000342
# TCN Epoch 24/50 | Train Loss: 0.000313 | Val Loss: 0.000130
# TCN Epoch 25/50 | Train Loss: 0.000286 | Val Loss: 0.000069
# TCN Epoch 26/50 | Train Loss: 0.000284 | Val Loss: 0.000172
# TCN Epoch 27/50 | Train Loss: 0.000281 | Val Loss: 0.000073
# TCN Epoch 28/50 | Train Loss: 0.000246 | Val Loss: 0.000068
# TCN Epoch 29/50 | Train Loss: 0.000227 | Val Loss: 0.000192
# TCN Epoch 30/50 | Train Loss: 0.000223 | Val Loss: 0.000098
# TCN Epoch 31/50 | Train Loss: 0.000206 | Val Loss: 0.000113
# TCN Epoch 32/50 | Train Loss: 0.000190 | Val Loss: 0.000074
# TCN Epoch 33/50 | Train Loss: 0.000177 | Val Loss: 0.000309
# TCN Epoch 34/50 | Train Loss: 0.000151 | Val Loss: 0.000103
# TCN Epoch 35/50 | Train Loss: 0.000143 | Val Loss: 0.000106
# TCN Epoch 36/50 | Train Loss: 0.000139 | Val Loss: 0.000145
# TCN Epoch 37/50 | Train Loss: 0.000132 | Val Loss: 0.000066
# TCN Epoch 38/50 | Train Loss: 0.000133 | Val Loss: 0.000116
# TCN Epoch 39/50 | Train Loss: 0.000117 | Val Loss: 0.000068
# TCN Epoch 40/50 | Train Loss: 0.000126 | Val Loss: 0.000094
# TCN Epoch 41/50 | Train Loss: 0.000104 | Val Loss: 0.000059
# TCN Epoch 42/50 | Train Loss: 0.000115 | Val Loss: 0.000105
# TCN Epoch 43/50 | Train Loss: 0.000100 | Val Loss: 0.000222
# TCN Epoch 44/50 | Train Loss: 0.000113 | Val Loss: 0.000325
# TCN Epoch 45/50 | Train Loss: 0.000111 | Val Loss: 0.000239
# TCN Epoch 46/50 | Train Loss: 0.000095 | Val Loss: 0.000087
# TCN Epoch 47/50 | Train Loss: 0.000091 | Val Loss: 0.000098
# TCN Epoch 48/50 | Train Loss: 0.000077 | Val Loss: 0.000061
# TCN Epoch 49/50 | Train Loss: 0.000086 | Val Loss: 0.000340
# TCN Epoch 50/50 | Train Loss: 0.000107 | Val Loss: 0.000045
# --- TCN Training Complete ---
#
# TCN Final R²: 0.9509, RMSE: 37.2363, MAE: 18.8410

# %%
# --- Part 3: LSTM ---
print("\n\n" + "=" * 60); print("PART 3: PROCEDURAL UNIDIRECTIONAL LSTM"); print("=" * 60)
LSTM_INPUT_DIM, LSTM_HIDDEN_DIM, LSTM_NUM_LAYERS, LSTM_OUTPUT_DIM, LSTM_DROPOUT = X_train.shape[2], 64, 1, 1, 0.0
LSTM_EPOCHS, LSTM_BATCH_SIZE, LSTM_LEARNING_RATE = 50, 32, 0.001
lstm_layer = nn.LSTM(LSTM_INPUT_DIM, LSTM_HIDDEN_DIM, LSTM_NUM_LAYERS, batch_first=True, dropout=LSTM_DROPOUT).to(device)
lstm_fc_layer = nn.Linear(LSTM_HIDDEN_DIM, LSTM_OUTPUT_DIM).to(device); lstm_optimizer = torch.optim.Adam(itertools.chain(lstm_layer.parameters(), lstm_fc_layer.parameters()), lr=LSTM_LEARNING_RATE)
lstm_criterion = nn.MSELoss(); lstm_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=LSTM_BATCH_SIZE, shuffle=True); loss_history['LSTM'], val_loss_history['LSTM'] = [], []
print("\n--- Starting LSTM Model Training ---")
for epoch in range(LSTM_EPOCHS):
    lstm_layer.train(); lstm_fc_layer.train(); running_loss = 0.0
    for xb, yb in lstm_train_loader:
        xb, yb = xb.to(device), yb.to(device); rnn_out, _ = lstm_layer(xb); pred = lstm_fc_layer(rnn_out[:, -1, :]); loss = lstm_criterion(pred, yb); lstm_optimizer.zero_grad(); loss.backward(); lstm_optimizer.step(); running_loss += loss.item()
    avg_epoch_loss = running_loss / len(lstm_train_loader); loss_history['LSTM'].append(avg_epoch_loss)
    with torch.no_grad(): rnn_out, _ = lstm_layer(X_val.to(device)); val_pred = lstm_fc_layer(rnn_out[:, -1, :]); val_loss = lstm_criterion(val_pred, Y_val.to(device)); val_loss_history['LSTM'].append(val_loss.item())
    print(f"LSTM Epoch {epoch+1:2d}/{LSTM_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")
print("--- LSTM Training Complete ---")
with torch.no_grad(): rnn_out, _ = lstm_layer(X_test.to(device)); lstm_preds_rescaled = target_scaler.inverse_transform(lstm_fc_layer(rnn_out[:, -1, :]).cpu().numpy()); lstm_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())
lstm_r2, lstm_rmse, lstm_mae = r2_score(lstm_true_rescaled, lstm_preds_rescaled), np.sqrt(mean_squared_error(lstm_true_rescaled, lstm_preds_rescaled)), mean_absolute_error(lstm_true_rescaled, lstm_preds_rescaled)
r2_scores['LSTM'], rmse_scores['LSTM'], mae_scores['LSTM'] = lstm_r2, lstm_rmse, lstm_mae
print(f"\nLSTM Final R²: {lstm_r2:.4f}, RMSE: {lstm_rmse:.4f}, MAE: {lstm_mae:.4f}")
plt.figure(figsize=(12, 5)); plt.plot(lstm_true_rescaled[:200], label='Actual'); plt.plot(lstm_preds_rescaled[:200], label='Predicted'); plt.title('LSTM'); 

plt.xlabel("Days")
plt.ylabel("Total")
plt.legend(); plt.grid(True); plt.show()
# Out:
# ============================================================
# PART 3: PROCEDURAL UNIDIRECTIONAL LSTM
# ============================================================
#
# --- Starting LSTM Model Training ---
# LSTM Epoch  1/50 | Train Loss: 0.009811 | Val Loss: 0.000935
# LSTM Epoch  2/50 | Train Loss: 0.000751 | Val Loss: 0.000992
# LSTM Epoch  3/50 | Train Loss: 0.000599 | Val Loss: 0.000410
# LSTM Epoch  4/50 | Train Loss: 0.000538 | Val Loss: 0.000207
# LSTM Epoch  5/50 | Train Loss: 0.000488 | Val Loss: 0.000106
# LSTM Epoch  6/50 | Train Loss: 0.000464 | Val Loss: 0.000113
# LSTM Epoch  7/50 | Train Loss: 0.000427 | Val Loss: 0.000081
# LSTM Epoch  8/50 | Train Loss: 0.000395 | Val Loss: 0.000325
# LSTM Epoch  9/50 | Train Loss: 0.000374 | Val Loss: 0.000062
# LSTM Epoch 10/50 | Train Loss: 0.000330 | Val Loss: 0.000034
# LSTM Epoch 11/50 | Train Loss: 0.000318 | Val Loss: 0.000072
# LSTM Epoch 12/50 | Train Loss: 0.000288 | Val Loss: 0.000076
# LSTM Epoch 13/50 | Train Loss: 0.000288 | Val Loss: 0.000060
# LSTM Epoch 14/50 | Train Loss: 0.000252 | Val Loss: 0.000039
# LSTM Epoch 15/50 | Train Loss: 0.000225 | Val Loss: 0.000045
# LSTM Epoch 16/50 | Train Loss: 0.000214 | Val Loss: 0.000072
# LSTM Epoch 17/50 | Train Loss: 0.000212 | Val Loss: 0.000154
# LSTM Epoch 18/50 | Train Loss: 0.000193 | Val Loss: 0.000034
# LSTM Epoch 19/50 | Train Loss: 0.000183 | Val Loss: 0.000045
# LSTM Epoch 20/50 | Train Loss: 0.000181 | Val Loss: 0.000140
# LSTM Epoch 21/50 | Train Loss: 0.000179 | Val Loss: 0.000045
# LSTM Epoch 22/50 | Train Loss: 0.000172 | Val Loss: 0.000137
# LSTM Epoch 23/50 | Train Loss: 0.000169 | Val Loss: 0.000073
# LSTM Epoch 24/50 | Train Loss: 0.000174 | Val Loss: 0.000091
# LSTM Epoch 25/50 | Train Loss: 0.000153 | Val Loss: 0.000171
# LSTM Epoch 26/50 | Train Loss: 0.000162 | Val Loss: 0.000054
# LSTM Epoch 27/50 | Train Loss: 0.000151 | Val Loss: 0.000050
# LSTM Epoch 28/50 | Train Loss: 0.000149 | Val Loss: 0.000177
# LSTM Epoch 29/50 | Train Loss: 0.000136 | Val Loss: 0.000331
# LSTM Epoch 30/50 | Train Loss: 0.000145 | Val Loss: 0.000305
# LSTM Epoch 31/50 | Train Loss: 0.000142 | Val Loss: 0.000086
# LSTM Epoch 32/50 | Train Loss: 0.000141 | Val Loss: 0.000164
# LSTM Epoch 33/50 | Train Loss: 0.000143 | Val Loss: 0.000053
# LSTM Epoch 34/50 | Train Loss: 0.000125 | Val Loss: 0.000056
# LSTM Epoch 35/50 | Train Loss: 0.000118 | Val Loss: 0.000040
# LSTM Epoch 36/50 | Train Loss: 0.000114 | Val Loss: 0.000119
# LSTM Epoch 37/50 | Train Loss: 0.000116 | Val Loss: 0.000110
# LSTM Epoch 38/50 | Train Loss: 0.000112 | Val Loss: 0.000061
# LSTM Epoch 39/50 | Train Loss: 0.000101 | Val Loss: 0.000108
# LSTM Epoch 40/50 | Train Loss: 0.000113 | Val Loss: 0.000086
# LSTM Epoch 41/50 | Train Loss: 0.000100 | Val Loss: 0.000080
# LSTM Epoch 42/50 | Train Loss: 0.000092 | Val Loss: 0.000129
# LSTM Epoch 43/50 | Train Loss: 0.000097 | Val Loss: 0.000067
# LSTM Epoch 44/50 | Train Loss: 0.000090 | Val Loss: 0.000083
# LSTM Epoch 45/50 | Train Loss: 0.000095 | Val Loss: 0.000079
# LSTM Epoch 46/50 | Train Loss: 0.000086 | Val Loss: 0.000081
# LSTM Epoch 47/50 | Train Loss: 0.000085 | Val Loss: 0.000053
# LSTM Epoch 48/50 | Train Loss: 0.000086 | Val Loss: 0.000062
# LSTM Epoch 49/50 | Train Loss: 0.000077 | Val Loss: 0.000091
# LSTM Epoch 50/50 | Train Loss: 0.000071 | Val Loss: 0.000085
# --- LSTM Training Complete ---
#
# LSTM Final R²: 0.9450, RMSE: 39.4193, MAE: 19.2940

# %%
# --- Part 4: BiLSTM ---
print("\n\n" + "=" * 60); print("PART 4: PROCEDURAL BIDIRECTIONAL LSTM (BILSTM)"); print("=" * 60)
BILSTM_INPUT_DIM, BILSTM_HIDDEN_DIM, BILSTM_NUM_LAYERS, BILSTM_OUTPUT_DIM, BILSTM_DROPOUT = X_train.shape[2], 64, 1, 1, 0.0
BILSTM_EPOCHS, BILSTM_BATCH_SIZE, BILSTM_LEARNING_RATE = 50, 32, 0.001
bilstm_layer = nn.LSTM(BILSTM_INPUT_DIM, BILSTM_HIDDEN_DIM, BILSTM_NUM_LAYERS, batch_first=True, bidirectional=True, dropout=BILSTM_DROPOUT).to(device)
bilstm_fc_layer = nn.Linear(BILSTM_HIDDEN_DIM * 2, BILSTM_OUTPUT_DIM).to(device); bilstm_optimizer = torch.optim.Adam(itertools.chain(bilstm_layer.parameters(), bilstm_fc_layer.parameters()), lr=BILSTM_LEARNING_RATE)
bilstm_criterion = nn.MSELoss(); bilstm_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=BILSTM_BATCH_SIZE, shuffle=True); loss_history['BiLSTM'], val_loss_history['BiLSTM'] = [], []
print("\n--- Starting BiLSTM Model Training ---")
for epoch in range(BILSTM_EPOCHS):
    bilstm_layer.train(); bilstm_fc_layer.train(); running_loss = 0.0
    for xb, yb in bilstm_train_loader:
        xb, yb = xb.to(device), yb.to(device); rnn_out, _ = bilstm_layer(xb); pred = bilstm_fc_layer(rnn_out[:, -1, :]); loss = bilstm_criterion(pred, yb); bilstm_optimizer.zero_grad(); loss.backward(); bilstm_optimizer.step(); running_loss += loss.item()
    avg_epoch_loss = running_loss / len(bilstm_train_loader); loss_history['BiLSTM'].append(avg_epoch_loss)
    with torch.no_grad(): rnn_out, _ = bilstm_layer(X_val.to(device)); val_pred = bilstm_fc_layer(rnn_out[:, -1, :]); val_loss = bilstm_criterion(val_pred, Y_val.to(device)); val_loss_history['BiLSTM'].append(val_loss.item())
    print(f"BiLSTM Epoch {epoch+1:2d}/{BILSTM_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")
print("--- BiLSTM Training Complete ---")
with torch.no_grad(): rnn_out, _ = bilstm_layer(X_test.to(device)); bilstm_preds_rescaled = target_scaler.inverse_transform(bilstm_fc_layer(rnn_out[:, -1, :]).cpu().numpy()); bilstm_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())
bilstm_r2, bilstm_rmse, bilstm_mae = r2_score(bilstm_true_rescaled, bilstm_preds_rescaled), np.sqrt(mean_squared_error(bilstm_true_rescaled, bilstm_preds_rescaled)), mean_absolute_error(bilstm_true_rescaled, bilstm_preds_rescaled)
r2_scores['BiLSTM'], rmse_scores['BiLSTM'], mae_scores['BiLSTM'] = bilstm_r2, bilstm_rmse, bilstm_mae
print(f"\nBiLSTM Final R²: {bilstm_r2:.4f}, RMSE: {bilstm_rmse:.4f}, MAE: {bilstm_mae:.4f}")
plt.figure(figsize=(12, 5)); plt.plot(bilstm_true_rescaled[:200], label='Actual'); plt.plot(bilstm_preds_rescaled[:200], label='Predicted'); plt.title('BiLSTM');

plt.xlabel("Days")
plt.ylabel("Total")
plt.legend(); plt.grid(True); plt.show()
# Out:
# ============================================================
# PART 4: PROCEDURAL BIDIRECTIONAL LSTM (BILSTM)
# ============================================================
#
# --- Starting BiLSTM Model Training ---
# BiLSTM Epoch  1/50 | Train Loss: 0.004588 | Val Loss: 0.000388
# BiLSTM Epoch  2/50 | Train Loss: 0.000612 | Val Loss: 0.000238
# BiLSTM Epoch  3/50 | Train Loss: 0.000422 | Val Loss: 0.000045
# BiLSTM Epoch  4/50 | Train Loss: 0.000348 | Val Loss: 0.000074
# BiLSTM Epoch  5/50 | Train Loss: 0.000314 | Val Loss: 0.000045
# BiLSTM Epoch  6/50 | Train Loss: 0.000292 | Val Loss: 0.000021
# BiLSTM Epoch  7/50 | Train Loss: 0.000281 | Val Loss: 0.000019
# BiLSTM Epoch  8/50 | Train Loss: 0.000265 | Val Loss: 0.000017
# BiLSTM Epoch  9/50 | Train Loss: 0.000256 | Val Loss: 0.000017
# BiLSTM Epoch 10/50 | Train Loss: 0.000249 | Val Loss: 0.000023
# BiLSTM Epoch 11/50 | Train Loss: 0.000240 | Val Loss: 0.000203
# BiLSTM Epoch 12/50 | Train Loss: 0.000226 | Val Loss: 0.000016
# BiLSTM Epoch 13/50 | Train Loss: 0.000219 | Val Loss: 0.000021
# BiLSTM Epoch 14/50 | Train Loss: 0.000214 | Val Loss: 0.000022
# BiLSTM Epoch 15/50 | Train Loss: 0.000206 | Val Loss: 0.000063
# BiLSTM Epoch 16/50 | Train Loss: 0.000202 | Val Loss: 0.000045
# BiLSTM Epoch 17/50 | Train Loss: 0.000202 | Val Loss: 0.000098
# BiLSTM Epoch 18/50 | Train Loss: 0.000201 | Val Loss: 0.000070
# BiLSTM Epoch 19/50 | Train Loss: 0.000191 | Val Loss: 0.000087
# BiLSTM Epoch 20/50 | Train Loss: 0.000178 | Val Loss: 0.000059
# BiLSTM Epoch 21/50 | Train Loss: 0.000176 | Val Loss: 0.000074
# BiLSTM Epoch 22/50 | Train Loss: 0.000171 | Val Loss: 0.000094
# BiLSTM Epoch 23/50 | Train Loss: 0.000166 | Val Loss: 0.000080
# BiLSTM Epoch 24/50 | Train Loss: 0.000160 | Val Loss: 0.000076
# BiLSTM Epoch 25/50 | Train Loss: 0.000160 | Val Loss: 0.000220
# BiLSTM Epoch 26/50 | Train Loss: 0.000160 | Val Loss: 0.000098
# BiLSTM Epoch 27/50 | Train Loss: 0.000148 | Val Loss: 0.000207
# BiLSTM Epoch 28/50 | Train Loss: 0.000150 | Val Loss: 0.000180
# BiLSTM Epoch 29/50 | Train Loss: 0.000142 | Val Loss: 0.000113
# BiLSTM Epoch 30/50 | Train Loss: 0.000137 | Val Loss: 0.000103
# BiLSTM Epoch 31/50 | Train Loss: 0.000137 | Val Loss: 0.000242
# BiLSTM Epoch 32/50 | Train Loss: 0.000133 | Val Loss: 0.000140
# BiLSTM Epoch 33/50 | Train Loss: 0.000135 | Val Loss: 0.000221
# BiLSTM Epoch 34/50 | Train Loss: 0.000130 | Val Loss: 0.000105
# BiLSTM Epoch 35/50 | Train Loss: 0.000127 | Val Loss: 0.000122
# BiLSTM Epoch 36/50 | Train Loss: 0.000134 | Val Loss: 0.000096
# BiLSTM Epoch 37/50 | Train Loss: 0.000126 | Val Loss: 0.000081
# BiLSTM Epoch 38/50 | Train Loss: 0.000112 | Val Loss: 0.000051
# BiLSTM Epoch 39/50 | Train Loss: 0.000109 | Val Loss: 0.000071
# BiLSTM Epoch 40/50 | Train Loss: 0.000113 | Val Loss: 0.000092
# BiLSTM Epoch 41/50 | Train Loss: 0.000110 | Val Loss: 0.000072
# BiLSTM Epoch 42/50 | Train Loss: 0.000099 | Val Loss: 0.000064
# BiLSTM Epoch 43/50 | Train Loss: 0.000093 | Val Loss: 0.000046
# BiLSTM Epoch 44/50 | Train Loss: 0.000099 | Val Loss: 0.000076
# BiLSTM Epoch 45/50 | Train Loss: 0.000095 | Val Loss: 0.000052
# BiLSTM Epoch 46/50 | Train Loss: 0.000089 | Val Loss: 0.000047
# BiLSTM Epoch 47/50 | Train Loss: 0.000084 | Val Loss: 0.000067
# BiLSTM Epoch 48/50 | Train Loss: 0.000082 | Val Loss: 0.000078
# BiLSTM Epoch 49/50 | Train Loss: 0.000077 | Val Loss: 0.000052
# BiLSTM Epoch 50/50 | Train Loss: 0.000074 | Val Loss: 0.000045
# --- BiLSTM Training Complete ---
#
# BiLSTM Final R²: 0.9050, RMSE: 51.8258, MAE: 23.7593

# %%
# --- Part 5: GRU ---
print("\n\n" + "=" * 60); print("PART 5: PROCEDURAL UNIDIRECTIONAL GRU"); print("=" * 60)
GRU_INPUT_DIM, GRU_HIDDEN_DIM, GRU_NUM_LAYERS, GRU_OUTPUT_DIM, GRU_DROPOUT = X_train.shape[2], 64, 1, 1, 0.0
GRU_EPOCHS, GRU_BATCH_SIZE, GRU_LEARNING_RATE = 50, 32, 0.001
gru_layer = nn.GRU(GRU_INPUT_DIM, GRU_HIDDEN_DIM, GRU_NUM_LAYERS, batch_first=True, dropout=GRU_DROPOUT).to(device)
gru_fc_layer = nn.Linear(GRU_HIDDEN_DIM, GRU_OUTPUT_DIM).to(device); gru_optimizer = torch.optim.Adam(itertools.chain(gru_layer.parameters(), gru_fc_layer.parameters()), lr=GRU_LEARNING_RATE)
gru_criterion = nn.MSELoss(); gru_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=GRU_BATCH_SIZE, shuffle=True); loss_history['GRU'], val_loss_history['GRU'] = [], []
print("\n--- Starting GRU Model Training ---")
for epoch in range(GRU_EPOCHS):
    gru_layer.train(); gru_fc_layer.train(); running_loss = 0.0
    for xb, yb in gru_train_loader:
        xb, yb = xb.to(device), yb.to(device); rnn_out, _ = gru_layer(xb); pred = gru_fc_layer(rnn_out[:, -1, :]); loss = gru_criterion(pred, yb); gru_optimizer.zero_grad(); loss.backward(); gru_optimizer.step(); running_loss += loss.item()
    avg_epoch_loss = running_loss / len(gru_train_loader); loss_history['GRU'].append(avg_epoch_loss)
    with torch.no_grad(): rnn_out, _ = gru_layer(X_val.to(device)); val_pred = gru_fc_layer(rnn_out[:, -1, :]); val_loss = gru_criterion(val_pred, Y_val.to(device)); val_loss_history['GRU'].append(val_loss.item())
    print(f"GRU Epoch {epoch+1:2d}/{GRU_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")
print("--- GRU Training Complete ---")
with torch.no_grad(): rnn_out, _ = gru_layer(X_test.to(device)); gru_preds_rescaled = target_scaler.inverse_transform(gru_fc_layer(rnn_out[:, -1, :]).cpu().numpy()); gru_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())
gru_r2, gru_rmse, gru_mae = r2_score(gru_true_rescaled, gru_preds_rescaled), np.sqrt(mean_squared_error(gru_true_rescaled, gru_preds_rescaled)), mean_absolute_error(gru_true_rescaled, gru_preds_rescaled)
r2_scores['GRU'], rmse_scores['GRU'], mae_scores['GRU'] = gru_r2, gru_rmse, gru_mae
print(f"\nGRU Final R²: {gru_r2:.4f}, RMSE: {gru_rmse:.4f}, MAE: {gru_mae:.4f}")
plt.figure(figsize=(12, 5)); plt.plot(gru_true_rescaled[:200], label='Actual'); plt.plot(gru_preds_rescaled[:200], label='Predicted'); plt.title('GRU');

plt.xlabel("Days")
plt.ylabel("Total")
plt.legend(); plt.grid(True); plt.show()
# Out:
# ============================================================
# PART 5: PROCEDURAL UNIDIRECTIONAL GRU
# ============================================================
#
# --- Starting GRU Model Training ---
# GRU Epoch  1/50 | Train Loss: 0.008573 | Val Loss: 0.000310
# GRU Epoch  2/50 | Train Loss: 0.000532 | Val Loss: 0.000101
# GRU Epoch  3/50 | Train Loss: 0.000446 | Val Loss: 0.000035
# GRU Epoch  4/50 | Train Loss: 0.000407 | Val Loss: 0.000038
# GRU Epoch  5/50 | Train Loss: 0.000362 | Val Loss: 0.000049
# GRU Epoch  6/50 | Train Loss: 0.000329 | Val Loss: 0.000018
# GRU Epoch  7/50 | Train Loss: 0.000316 | Val Loss: 0.000017
# GRU Epoch  8/50 | Train Loss: 0.000296 | Val Loss: 0.000011
# GRU Epoch  9/50 | Train Loss: 0.000260 | Val Loss: 0.000011
# GRU Epoch 10/50 | Train Loss: 0.000249 | Val Loss: 0.000054
# GRU Epoch 11/50 | Train Loss: 0.000224 | Val Loss: 0.000076
# GRU Epoch 12/50 | Train Loss: 0.000207 | Val Loss: 0.000015
# GRU Epoch 13/50 | Train Loss: 0.000198 | Val Loss: 0.000109
# GRU Epoch 14/50 | Train Loss: 0.000195 | Val Loss: 0.000063
# GRU Epoch 15/50 | Train Loss: 0.000186 | Val Loss: 0.000049
# GRU Epoch 16/50 | Train Loss: 0.000184 | Val Loss: 0.000032
# GRU Epoch 17/50 | Train Loss: 0.000174 | Val Loss: 0.000043
# GRU Epoch 18/50 | Train Loss: 0.000173 | Val Loss: 0.000038
# GRU Epoch 19/50 | Train Loss: 0.000173 | Val Loss: 0.000206
# GRU Epoch 20/50 | Train Loss: 0.000171 | Val Loss: 0.000049
# GRU Epoch 21/50 | Train Loss: 0.000158 | Val Loss: 0.000041
# GRU Epoch 22/50 | Train Loss: 0.000158 | Val Loss: 0.000042
# GRU Epoch 23/50 | Train Loss: 0.000149 | Val Loss: 0.000100
# GRU Epoch 24/50 | Train Loss: 0.000148 | Val Loss: 0.000052
# GRU Epoch 25/50 | Train Loss: 0.000152 | Val Loss: 0.000149
# GRU Epoch 26/50 | Train Loss: 0.000144 | Val Loss: 0.000063
# GRU Epoch 27/50 | Train Loss: 0.000145 | Val Loss: 0.000181
# GRU Epoch 28/50 | Train Loss: 0.000149 | Val Loss: 0.000107
# GRU Epoch 29/50 | Train Loss: 0.000133 | Val Loss: 0.000087
# GRU Epoch 30/50 | Train Loss: 0.000135 | Val Loss: 0.000071
# GRU Epoch 31/50 | Train Loss: 0.000127 | Val Loss: 0.000057
# GRU Epoch 32/50 | Train Loss: 0.000121 | Val Loss: 0.000068
# GRU Epoch 33/50 | Train Loss: 0.000116 | Val Loss: 0.000074
# GRU Epoch 34/50 | Train Loss: 0.000121 | Val Loss: 0.000089
# GRU Epoch 35/50 | Train Loss: 0.000120 | Val Loss: 0.000093
# GRU Epoch 36/50 | Train Loss: 0.000111 | Val Loss: 0.000056
# GRU Epoch 37/50 | Train Loss: 0.000106 | Val Loss: 0.000119
# GRU Epoch 38/50 | Train Loss: 0.000105 | Val Loss: 0.000056
# GRU Epoch 39/50 | Train Loss: 0.000103 | Val Loss: 0.000086
# GRU Epoch 40/50 | Train Loss: 0.000098 | Val Loss: 0.000056
# GRU Epoch 41/50 | Train Loss: 0.000097 | Val Loss: 0.000050
# GRU Epoch 42/50 | Train Loss: 0.000097 | Val Loss: 0.000063
# GRU Epoch 43/50 | Train Loss: 0.000086 | Val Loss: 0.000074
# GRU Epoch 44/50 | Train Loss: 0.000095 | Val Loss: 0.000080
# GRU Epoch 45/50 | Train Loss: 0.000087 | Val Loss: 0.000060
# GRU Epoch 46/50 | Train Loss: 0.000081 | Val Loss: 0.000051
# GRU Epoch 47/50 | Train Loss: 0.000078 | Val Loss: 0.000181
# GRU Epoch 48/50 | Train Loss: 0.000083 | Val Loss: 0.000059
# GRU Epoch 49/50 | Train Loss: 0.000071 | Val Loss: 0.000033
# GRU Epoch 50/50 | Train Loss: 0.000073 | Val Loss: 0.000051
# --- GRU Training Complete ---
#
# GRU Final R²: 0.9698, RMSE: 29.2377, MAE: 12.7870

# %%
# --- Part 6: BiGRU ---
print("\n\n" + "=" * 60); print("PART 6: PROCEDURAL BIDIRECTIONAL GRU (BIGRU)"); print("=" * 60)
BIGRU_INPUT_DIM, BIGRU_HIDDEN_DIM, BIGRU_NUM_LAYERS, BIGRU_OUTPUT_DIM, BIGRU_DROPOUT = X_train.shape[2], 64, 1, 1, 0.0
BIGRU_EPOCHS, BIGRU_BATCH_SIZE, BIGRU_LEARNING_RATE = 50, 32, 0.001
bigru_layer = nn.GRU(BIGRU_INPUT_DIM, BIGRU_HIDDEN_DIM, BIGRU_NUM_LAYERS, batch_first=True, bidirectional=True, dropout=BIGRU_DROPOUT).to(device)
bigru_fc_layer = nn.Linear(BIGRU_HIDDEN_DIM * 2, BIGRU_OUTPUT_DIM).to(device); bigru_optimizer = torch.optim.Adam(itertools.chain(bigru_layer.parameters(), bigru_fc_layer.parameters()), lr=BIGRU_LEARNING_RATE)
bigru_criterion = nn.MSELoss(); bigru_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=BIGRU_BATCH_SIZE, shuffle=True); loss_history['BiGRU'], val_loss_history['BiGRU'] = [], []
print("\n--- Starting BiGRU Model Training ---")
for epoch in range(BIGRU_EPOCHS):
    bigru_layer.train(); bigru_fc_layer.train(); running_loss = 0.0
    for xb, yb in bigru_train_loader:
        xb, yb = xb.to(device), yb.to(device); rnn_out, _ = bigru_layer(xb); pred = bigru_fc_layer(rnn_out[:, -1, :]); loss = bigru_criterion(pred, yb); bigru_optimizer.zero_grad(); loss.backward(); bigru_optimizer.step(); running_loss += loss.item()
    avg_epoch_loss = running_loss / len(bigru_train_loader); loss_history['BiGRU'].append(avg_epoch_loss)
    with torch.no_grad(): rnn_out, _ = bigru_layer(X_val.to(device)); val_pred = bigru_fc_layer(rnn_out[:, -1, :]); val_loss = bigru_criterion(val_pred, Y_val.to(device)); val_loss_history['BiGRU'].append(val_loss.item())
    print(f"BiGRU Epoch {epoch+1:2d}/{BIGRU_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")
print("--- BiGRU Training Complete ---")
with torch.no_grad(): rnn_out, _ = bigru_layer(X_test.to(device)); bigru_preds_rescaled = target_scaler.inverse_transform(bigru_fc_layer(rnn_out[:, -1, :]).cpu().numpy()); bigru_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())
bigru_r2, bigru_rmse, bigru_mae = r2_score(bigru_true_rescaled, bigru_preds_rescaled), np.sqrt(mean_squared_error(bigru_true_rescaled, bigru_preds_rescaled)), mean_absolute_error(bigru_true_rescaled, bigru_preds_rescaled)
r2_scores['BiGRU'], rmse_scores['BiGRU'], mae_scores['BiGRU'] = bigru_r2, bigru_rmse, bigru_mae
print(f"\nBiGRU Final R²: {bigru_r2:.4f}, RMSE: {bigru_rmse:.4f}, MAE: {bigru_mae:.4f}")
plt.figure(figsize=(12, 5)); plt.plot(bigru_true_rescaled[:200], label='Actual'); plt.plot(bigru_preds_rescaled[:200], label='Predicted'); plt.title('BiGRU');

plt.xlabel("Days")
plt.ylabel("Total")
plt.legend(); plt.grid(True); plt.show()
# Out:
# ============================================================
# PART 6: PROCEDURAL BIDIRECTIONAL GRU (BIGRU)
# ============================================================
#
# --- Starting BiGRU Model Training ---
# BiGRU Epoch  1/50 | Train Loss: 0.006278 | Val Loss: 0.000130
# BiGRU Epoch  2/50 | Train Loss: 0.000476 | Val Loss: 0.000047
# BiGRU Epoch  3/50 | Train Loss: 0.000384 | Val Loss: 0.000082
# BiGRU Epoch  4/50 | Train Loss: 0.000328 | Val Loss: 0.000010
# BiGRU Epoch  5/50 | Train Loss: 0.000298 | Val Loss: 0.000093
# BiGRU Epoch  6/50 | Train Loss: 0.000286 | Val Loss: 0.000083
# BiGRU Epoch  7/50 | Train Loss: 0.000280 | Val Loss: 0.000038
# BiGRU Epoch  8/50 | Train Loss: 0.000244 | Val Loss: 0.000025
# BiGRU Epoch  9/50 | Train Loss: 0.000231 | Val Loss: 0.000048
# BiGRU Epoch 10/50 | Train Loss: 0.000231 | Val Loss: 0.000027
# BiGRU Epoch 11/50 | Train Loss: 0.000218 | Val Loss: 0.000030
# BiGRU Epoch 12/50 | Train Loss: 0.000209 | Val Loss: 0.000086
# BiGRU Epoch 13/50 | Train Loss: 0.000202 | Val Loss: 0.000031
# BiGRU Epoch 14/50 | Train Loss: 0.000187 | Val Loss: 0.000062
# BiGRU Epoch 15/50 | Train Loss: 0.000194 | Val Loss: 0.000047
# BiGRU Epoch 16/50 | Train Loss: 0.000181 | Val Loss: 0.000030
# BiGRU Epoch 17/50 | Train Loss: 0.000172 | Val Loss: 0.000040
# BiGRU Epoch 18/50 | Train Loss: 0.000172 | Val Loss: 0.000052
# BiGRU Epoch 19/50 | Train Loss: 0.000177 | Val Loss: 0.000060
# BiGRU Epoch 20/50 | Train Loss: 0.000163 | Val Loss: 0.000055
# BiGRU Epoch 21/50 | Train Loss: 0.000161 | Val Loss: 0.000056
# BiGRU Epoch 22/50 | Train Loss: 0.000163 | Val Loss: 0.000122
# BiGRU Epoch 23/50 | Train Loss: 0.000163 | Val Loss: 0.000361
# BiGRU Epoch 24/50 | Train Loss: 0.000156 | Val Loss: 0.000129
# BiGRU Epoch 25/50 | Train Loss: 0.000148 | Val Loss: 0.000121
# BiGRU Epoch 26/50 | Train Loss: 0.000145 | Val Loss: 0.000060
# BiGRU Epoch 27/50 | Train Loss: 0.000151 | Val Loss: 0.000060
# BiGRU Epoch 28/50 | Train Loss: 0.000145 | Val Loss: 0.000102
# BiGRU Epoch 29/50 | Train Loss: 0.000138 | Val Loss: 0.000099
# BiGRU Epoch 30/50 | Train Loss: 0.000145 | Val Loss: 0.000091
# BiGRU Epoch 31/50 | Train Loss: 0.000140 | Val Loss: 0.000082
# BiGRU Epoch 32/50 | Train Loss: 0.000128 | Val Loss: 0.000120
# BiGRU Epoch 33/50 | Train Loss: 0.000130 | Val Loss: 0.000064
# BiGRU Epoch 34/50 | Train Loss: 0.000127 | Val Loss: 0.000054
# BiGRU Epoch 35/50 | Train Loss: 0.000119 | Val Loss: 0.000103
# BiGRU Epoch 36/50 | Train Loss: 0.000120 | Val Loss: 0.000057
# BiGRU Epoch 37/50 | Train Loss: 0.000122 | Val Loss: 0.000060
# BiGRU Epoch 38/50 | Train Loss: 0.000109 | Val Loss: 0.000083
# BiGRU Epoch 39/50 | Train Loss: 0.000113 | Val Loss: 0.000096
# BiGRU Epoch 40/50 | Train Loss: 0.000109 | Val Loss: 0.000052
# BiGRU Epoch 41/50 | Train Loss: 0.000103 | Val Loss: 0.000053
# BiGRU Epoch 42/50 | Train Loss: 0.000096 | Val Loss: 0.000055
# BiGRU Epoch 43/50 | Train Loss: 0.000093 | Val Loss: 0.000072
# BiGRU Epoch 44/50 | Train Loss: 0.000093 | Val Loss: 0.000042
# BiGRU Epoch 45/50 | Train Loss: 0.000090 | Val Loss: 0.000128
# BiGRU Epoch 46/50 | Train Loss: 0.000085 | Val Loss: 0.000047
# BiGRU Epoch 47/50 | Train Loss: 0.000079 | Val Loss: 0.000035
# BiGRU Epoch 48/50 | Train Loss: 0.000081 | Val Loss: 0.000082
# BiGRU Epoch 49/50 | Train Loss: 0.000088 | Val Loss: 0.000040
# BiGRU Epoch 50/50 | Train Loss: 0.000071 | Val Loss: 0.000068
# --- BiGRU Training Complete ---
#
# BiGRU Final R²: 0.9663, RMSE: 30.8577, MAE: 15.3083

# %%
# ==============================================================================
# Part 7: Procedural "Pure" Graph Convolutional Network (GCN) - Procedural Version
# ==============================================================================
print("\n\n" + "=" * 60)
print("PART 7: PROCEDURAL 'PURE' GRAPH CONVOLUTIONAL NETWORK (GCN) - Procedural Version")
print("=" * 60)

print("\n--- Setting up GCN Model Parameters ---")
GCN_INPUT_DIM = X_train.shape[2]
GCN_HIDDEN_DIM = 128
GCN_OUTPUT_DIM = 1
GCN_DROPOUT = 0.3
GCN_EPOCHS = 50
GCN_BATCH_SIZE = 32
GCN_LEARNING_RATE = 0.0001

# Layers
gcn_linear1 = nn.Linear(GCN_INPUT_DIM, GCN_HIDDEN_DIM).to(device)
gcn_linear2 = nn.Linear(GCN_HIDDEN_DIM, GCN_HIDDEN_DIM).to(device)
fc_out_gcn = nn.Linear(GCN_HIDDEN_DIM, GCN_OUTPUT_DIM).to(device)
dropout_gcn = nn.Dropout(GCN_DROPOUT)

# Optimizer & Loss
gcn_params = list(gcn_linear1.parameters()) + list(gcn_linear2.parameters()) + list(fc_out_gcn.parameters())
gcn_optimizer = torch.optim.Adam(gcn_params, lr=GCN_LEARNING_RATE)
gcn_criterion = nn.MSELoss()
gcn_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=GCN_BATCH_SIZE, shuffle=True)

loss_history['GCN'], val_loss_history['GCN'] = [], []

# Forward Function
def forward_gcn(x, adj):
    gcn_features_over_time = []
    for t in range(x.size(1)):
        xt = x[:, t, :]
        xt = torch.matmul(xt, adj)
        xt = F.relu(gcn_linear1(xt))
        xt = F.relu(gcn_linear2(xt))
        xt = dropout_gcn(xt)
        gcn_features_over_time.append(xt.unsqueeze(1))
    x_gcn_seq = torch.cat(gcn_features_over_time, dim=1)
    last_step_features = x_gcn_seq[:, -1, :]
    return fc_out_gcn(last_step_features)

# Training Loop
print("\n--- Starting GCN Model Training ---")
for epoch in range(GCN_EPOCHS):
    gcn_linear1.train(); gcn_linear2.train(); fc_out_gcn.train()
    running_loss = 0.0
    for xb, yb in gcn_train_loader:
        xb, yb = xb.to(device), yb.to(device)
        pred = forward_gcn(xb, adj_tensor)
        loss = gcn_criterion(pred, yb)
        gcn_optimizer.zero_grad()
        loss.backward()
        gcn_optimizer.step()
        running_loss += loss.item()
    avg_epoch_loss = running_loss / len(gcn_train_loader)
    loss_history['GCN'].append(avg_epoch_loss)

    with torch.no_grad():
        val_pred = forward_gcn(X_val.to(device), adj_tensor)
        val_loss = gcn_criterion(val_pred, Y_val.to(device))
        val_loss_history['GCN'].append(val_loss.item())

    print(f"GCN Epoch {epoch+1:2d}/{GCN_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")

print("--- GCN Training Complete ---")

# Evaluation
with torch.no_grad():
    gcn_preds = forward_gcn(X_test.to(device), adj_tensor)
    gcn_preds_rescaled = target_scaler.inverse_transform(gcn_preds.cpu().numpy())
    gcn_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())

gcn_r2 = r2_score(gcn_true_rescaled, gcn_preds_rescaled)
gcn_rmse = np.sqrt(mean_squared_error(gcn_true_rescaled, gcn_preds_rescaled))
gcn_mae = mean_absolute_error(gcn_true_rescaled, gcn_preds_rescaled)
r2_scores['GCN'], rmse_scores['GCN'], mae_scores['GCN'] = gcn_r2, gcn_rmse, gcn_mae

print(f"\nGCN Final R²: {gcn_r2:.4f}, RMSE: {gcn_rmse:.4f}, MAE: {gcn_mae:.4f}")
plt.figure(figsize=(12, 5))
plt.plot(gcn_true_rescaled[:200], label='Actual')
plt.plot(gcn_preds_rescaled[:200], label='Predicted')
plt.title('GCN (Procedural)')
plt.xlabel("Days")
plt.ylabel("Total")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ============================================================
# PART 7: PROCEDURAL 'PURE' GRAPH CONVOLUTIONAL NETWORK (GCN) - Procedural Version
# ============================================================
#
# --- Setting up GCN Model Parameters ---
#
# --- Starting GCN Model Training ---
# GCN Epoch  1/50 | Train Loss: 0.019981 | Val Loss: 0.006754
# GCN Epoch  2/50 | Train Loss: 0.004408 | Val Loss: 0.003957
# GCN Epoch  3/50 | Train Loss: 0.002759 | Val Loss: 0.002540
# GCN Epoch  4/50 | Train Loss: 0.001979 | Val Loss: 0.002085
# GCN Epoch  5/50 | Train Loss: 0.001676 | Val Loss: 0.001821
# GCN Epoch  6/50 | Train Loss: 0.001474 | Val Loss: 0.001350
# GCN Epoch  7/50 | Train Loss: 0.001332 | Val Loss: 0.001461
# GCN Epoch  8/50 | Train Loss: 0.001258 | Val Loss: 0.001288
# GCN Epoch  9/50 | Train Loss: 0.001160 | Val Loss: 0.001383
# GCN Epoch 10/50 | Train Loss: 0.001135 | Val Loss: 0.001405
# GCN Epoch 11/50 | Train Loss: 0.001098 | Val Loss: 0.001276
# GCN Epoch 12/50 | Train Loss: 0.001137 | Val Loss: 0.001181
# GCN Epoch 13/50 | Train Loss: 0.001049 | Val Loss: 0.001191
# GCN Epoch 14/50 | Train Loss: 0.001022 | Val Loss: 0.001235
# GCN Epoch 15/50 | Train Loss: 0.001016 | Val Loss: 0.001116
# GCN Epoch 16/50 | Train Loss: 0.000992 | Val Loss: 0.001149
# GCN Epoch 17/50 | Train Loss: 0.001005 | Val Loss: 0.001268
# GCN Epoch 18/50 | Train Loss: 0.000960 | Val Loss: 0.001163
# GCN Epoch 19/50 | Train Loss: 0.001021 | Val Loss: 0.001188
# GCN Epoch 20/50 | Train Loss: 0.000908 | Val Loss: 0.001147
# GCN Epoch 21/50 | Train Loss: 0.000930 | Val Loss: 0.001169
# GCN Epoch 22/50 | Train Loss: 0.000890 | Val Loss: 0.001151
# GCN Epoch 23/50 | Train Loss: 0.000897 | Val Loss: 0.001123
# GCN Epoch 24/50 | Train Loss: 0.000849 | Val Loss: 0.000962
# GCN Epoch 25/50 | Train Loss: 0.000832 | Val Loss: 0.001036
# GCN Epoch 26/50 | Train Loss: 0.000826 | Val Loss: 0.000995
# GCN Epoch 27/50 | Train Loss: 0.000798 | Val Loss: 0.000861
# GCN Epoch 28/50 | Train Loss: 0.000784 | Val Loss: 0.000911
# GCN Epoch 29/50 | Train Loss: 0.000764 | Val Loss: 0.000855
# GCN Epoch 30/50 | Train Loss: 0.000697 | Val Loss: 0.000840
# GCN Epoch 31/50 | Train Loss: 0.000712 | Val Loss: 0.000842
# GCN Epoch 32/50 | Train Loss: 0.000656 | Val Loss: 0.000781
# GCN Epoch 33/50 | Train Loss: 0.000658 | Val Loss: 0.000799
# GCN Epoch 34/50 | Train Loss: 0.000624 | Val Loss: 0.000839
# GCN Epoch 35/50 | Train Loss: 0.000608 | Val Loss: 0.000870
# GCN Epoch 36/50 | Train Loss: 0.000577 | Val Loss: 0.000758
# GCN Epoch 37/50 | Train Loss: 0.000577 | Val Loss: 0.000874
# GCN Epoch 38/50 | Train Loss: 0.000545 | Val Loss: 0.000776
# GCN Epoch 39/50 | Train Loss: 0.000511 | Val Loss: 0.000697
# GCN Epoch 40/50 | Train Loss: 0.000500 | Val Loss: 0.000750
# GCN Epoch 41/50 | Train Loss: 0.000481 | Val Loss: 0.000674
# GCN Epoch 42/50 | Train Loss: 0.000472 | Val Loss: 0.000772
# GCN Epoch 43/50 | Train Loss: 0.000463 | Val Loss: 0.000768
# GCN Epoch 44/50 | Train Loss: 0.000441 | Val Loss: 0.000615
# GCN Epoch 45/50 | Train Loss: 0.000436 | Val Loss: 0.000781
# GCN Epoch 46/50 | Train Loss: 0.000396 | Val Loss: 0.000821
# GCN Epoch 47/50 | Train Loss: 0.000411 | Val Loss: 0.000752
# GCN Epoch 48/50 | Train Loss: 0.000382 | Val Loss: 0.000675
# GCN Epoch 49/50 | Train Loss: 0.000365 | Val Loss: 0.000796
# GCN Epoch 50/50 | Train Loss: 0.000355 | Val Loss: 0.000653
# --- GCN Training Complete ---
#
# GCN Final R²: 0.7905, RMSE: 76.9539, MAE: 56.2883

# %%
# ==============================================================================
# Part 10: PROCEDURAL HYBRID MODEL (TCN + GCN)
# ==============================================================================
print("\n\n" + "=" * 60)
print("PART 10: PROCEDURAL HYBRID MODEL (TCN + GCN)")
print("=" * 60)

HYBRID_INPUT_DIM, TCN_HIDDEN_DIM, GCN_HIDDEN_DIM, HYBRID_OUTPUT_DIM = X_train.shape[2], 64, 128, 1
KERNEL_SIZE, TCN_DROPOUT, HYBRID_DROPOUT = 3, 0.2, 0.3
HYBRID_EPOCHS, HYBRID_BATCH_SIZE, HYBRID_LR = 50, 32, 0.001

# TCN Component
tcn_layer = nn.Sequential(
    nn.Conv1d(HYBRID_INPUT_DIM, TCN_HIDDEN_DIM, kernel_size=KERNEL_SIZE, padding=(KERNEL_SIZE - 1) // 2),
    nn.ReLU(),
    nn.Dropout(TCN_DROPOUT)
).to(device)

# GCN Component
tcn_gcn1 = nn.Linear(HYBRID_INPUT_DIM, GCN_HIDDEN_DIM).to(device)
tcn_gcn2 = nn.Linear(GCN_HIDDEN_DIM, GCN_HIDDEN_DIM).to(device)
tcn_gcn_dropout = nn.Dropout(HYBRID_DROPOUT)

# Output Layer
tcn_gcn_fc = nn.Linear(TCN_HIDDEN_DIM + GCN_HIDDEN_DIM, HYBRID_OUTPUT_DIM).to(device)

# Optimizer & Loss
tcn_gcn_params = list(tcn_layer.parameters()) + list(tcn_gcn1.parameters()) + list(tcn_gcn2.parameters()) + list(tcn_gcn_fc.parameters())
tcn_gcn_optimizer = torch.optim.Adam(tcn_gcn_params, lr=HYBRID_LR)
tcn_gcn_criterion = nn.MSELoss()
tcn_gcn_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=HYBRID_BATCH_SIZE, shuffle=True)
loss_history['Hybrid_TCN_GCN'], val_loss_history['Hybrid_TCN_GCN'] = [], []

print("\n--- Starting Hybrid TCN-GCN Model Training ---")
for epoch in range(HYBRID_EPOCHS):
    tcn_layer.train(); tcn_gcn1.train(); tcn_gcn2.train(); tcn_gcn_fc.train(); running_loss = 0.0
    for xb, yb in tcn_gcn_train_loader:
        xb, yb = xb.to(device), yb.to(device)
        tcn_in = xb.permute(0, 2, 1)
        tcn_feat = tcn_layer(tcn_in)
        tcn_feat_last = tcn_feat[:, :, -1]

        gcn_feats = []
        for t in range(xb.size(1)):
            xt = xb[:, t, :]
            xt = torch.matmul(xt, adj_tensor)
            xt = F.relu(tcn_gcn1(xt))
            xt = F.relu(tcn_gcn2(xt))
            xt = tcn_gcn_dropout(xt)
            gcn_feats.append(xt.unsqueeze(1))
        gcn_seq = torch.cat(gcn_feats, dim=1)
        gcn_feat = gcn_seq[:, -1, :]

        combined = torch.cat([tcn_feat_last, gcn_feat], dim=1)
        pred = tcn_gcn_fc(combined)
        loss = tcn_gcn_criterion(pred, yb)
        tcn_gcn_optimizer.zero_grad(); loss.backward(); tcn_gcn_optimizer.step(); running_loss += loss.item()

    avg_epoch_loss = running_loss / len(tcn_gcn_train_loader)
    loss_history['Hybrid_TCN_GCN'].append(avg_epoch_loss)

    with torch.no_grad():
        tcn_val_in = X_val.permute(0, 2, 1).to(device)
        tcn_val_feat = tcn_layer(tcn_val_in)
        tcn_val_last = tcn_val_feat[:, :, -1]

        gcn_val_feats = []
        for t in range(X_val.size(1)):
            xt = X_val[:, t, :].to(device)
            xt = torch.matmul(xt, adj_tensor)
            xt = F.relu(tcn_gcn1(xt))
            xt = F.relu(tcn_gcn2(xt))
            xt = tcn_gcn_dropout(xt)
            gcn_val_feats.append(xt.unsqueeze(1))
        gcn_val_seq = torch.cat(gcn_val_feats, dim=1)
        gcn_val_feat = gcn_val_seq[:, -1, :]

        val_combined = torch.cat([tcn_val_last, gcn_val_feat], dim=1)
        val_pred = tcn_gcn_fc(val_combined)
        val_loss = tcn_gcn_criterion(val_pred, Y_val.to(device))
        val_loss_history['Hybrid_TCN_GCN'].append(val_loss.item())

    print(f"Hybrid TCN-GCN Epoch {epoch+1:2d}/{HYBRID_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")

print("--- Hybrid TCN-GCN Training Complete ---")

# Final Evaluation
with torch.no_grad():
    tcn_test_in = X_test.permute(0, 2, 1).to(device)
    tcn_test_feat = tcn_layer(tcn_test_in)
    tcn_test_last = tcn_test_feat[:, :, -1]

    gcn_test_feats = []
    for t in range(X_test.size(1)):
        xt = X_test[:, t, :].to(device)
        xt = torch.matmul(xt, adj_tensor)
        xt = F.relu(tcn_gcn1(xt))
        xt = F.relu(tcn_gcn2(xt))
        xt = tcn_gcn_dropout(xt)
        gcn_test_feats.append(xt.unsqueeze(1))
    gcn_test_seq = torch.cat(gcn_test_feats, dim=1)
    gcn_test_feat = gcn_test_seq[:, -1, :]

    final_combined = torch.cat([tcn_test_last, gcn_test_feat], dim=1)
    hybrid_preds = tcn_gcn_fc(final_combined)

    hybrid_preds_rescaled = target_scaler.inverse_transform(hybrid_preds.cpu().numpy())
    hybrid_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())

hybrid_r2 = r2_score(hybrid_true_rescaled, hybrid_preds_rescaled)
hybrid_rmse = np.sqrt(mean_squared_error(hybrid_true_rescaled, hybrid_preds_rescaled))
hybrid_mae = mean_absolute_error(hybrid_true_rescaled, hybrid_preds_rescaled)

r2_scores['Hybrid_TCN_GCN'] = hybrid_r2
rmse_scores['Hybrid_TCN_GCN'] = hybrid_rmse
mae_scores['Hybrid_TCN_GCN'] = hybrid_mae

print(f"\nHybrid TCN-GCN Final R²: {hybrid_r2:.4f}, RMSE: {hybrid_rmse:.4f}, MAE: {hybrid_mae:.4f}")
plt.figure(figsize=(12, 5))
plt.plot(hybrid_true_rescaled[:200], label='Actual')
plt.plot(hybrid_preds_rescaled[:200], label='Predicted')
plt.title('Hybrid TCN-GCN')
plt.xlabel("Days")
plt.ylabel("Total")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ============================================================
# PART 10: PROCEDURAL HYBRID MODEL (TCN + GCN)
# ============================================================
#
# --- Starting Hybrid TCN-GCN Model Training ---
# Hybrid TCN-GCN Epoch  1/50 | Train Loss: 0.004246 | Val Loss: 0.001361
# Hybrid TCN-GCN Epoch  2/50 | Train Loss: 0.001166 | Val Loss: 0.001644
# Hybrid TCN-GCN Epoch  3/50 | Train Loss: 0.001036 | Val Loss: 0.000971
# Hybrid TCN-GCN Epoch  4/50 | Train Loss: 0.000881 | Val Loss: 0.000765
# Hybrid TCN-GCN Epoch  5/50 | Train Loss: 0.000754 | Val Loss: 0.001059
# Hybrid TCN-GCN Epoch  6/50 | Train Loss: 0.000662 | Val Loss: 0.000930
# Hybrid TCN-GCN Epoch  7/50 | Train Loss: 0.000618 | Val Loss: 0.000809
# Hybrid TCN-GCN Epoch  8/50 | Train Loss: 0.000566 | Val Loss: 0.000837
# Hybrid TCN-GCN Epoch  9/50 | Train Loss: 0.000492 | Val Loss: 0.000503
# Hybrid TCN-GCN Epoch 10/50 | Train Loss: 0.000485 | Val Loss: 0.000622
# Hybrid TCN-GCN Epoch 11/50 | Train Loss: 0.000417 | Val Loss: 0.000822
# Hybrid TCN-GCN Epoch 12/50 | Train Loss: 0.000366 | Val Loss: 0.000424
# Hybrid TCN-GCN Epoch 13/50 | Train Loss: 0.000356 | Val Loss: 0.001133
# Hybrid TCN-GCN Epoch 14/50 | Train Loss: 0.000294 | Val Loss: 0.000652
# Hybrid TCN-GCN Epoch 15/50 | Train Loss: 0.000239 | Val Loss: 0.001130
# Hybrid TCN-GCN Epoch 16/50 | Train Loss: 0.000225 | Val Loss: 0.001463
# Hybrid TCN-GCN Epoch 17/50 | Train Loss: 0.000193 | Val Loss: 0.000657
# Hybrid TCN-GCN Epoch 18/50 | Train Loss: 0.000177 | Val Loss: 0.001176
# Hybrid TCN-GCN Epoch 19/50 | Train Loss: 0.000157 | Val Loss: 0.001529
# Hybrid TCN-GCN Epoch 20/50 | Train Loss: 0.000167 | Val Loss: 0.001036
# Hybrid TCN-GCN Epoch 21/50 | Train Loss: 0.000171 | Val Loss: 0.001002
# Hybrid TCN-GCN Epoch 22/50 | Train Loss: 0.000150 | Val Loss: 0.000988
# Hybrid TCN-GCN Epoch 23/50 | Train Loss: 0.000161 | Val Loss: 0.001387
# Hybrid TCN-GCN Epoch 24/50 | Train Loss: 0.000152 | Val Loss: 0.002053
# Hybrid TCN-GCN Epoch 25/50 | Train Loss: 0.000110 | Val Loss: 0.000810
# Hybrid TCN-GCN Epoch 26/50 | Train Loss: 0.000108 | Val Loss: 0.000922
# Hybrid TCN-GCN Epoch 27/50 | Train Loss: 0.000157 | Val Loss: 0.001324
# Hybrid TCN-GCN Epoch 28/50 | Train Loss: 0.000127 | Val Loss: 0.000989
# Hybrid TCN-GCN Epoch 29/50 | Train Loss: 0.000123 | Val Loss: 0.002178
# Hybrid TCN-GCN Epoch 30/50 | Train Loss: 0.000129 | Val Loss: 0.000792
# Hybrid TCN-GCN Epoch 31/50 | Train Loss: 0.000124 | Val Loss: 0.001777
# Hybrid TCN-GCN Epoch 32/50 | Train Loss: 0.000111 | Val Loss: 0.001150
# Hybrid TCN-GCN Epoch 33/50 | Train Loss: 0.000114 | Val Loss: 0.001701
# Hybrid TCN-GCN Epoch 34/50 | Train Loss: 0.000138 | Val Loss: 0.001598
# Hybrid TCN-GCN Epoch 35/50 | Train Loss: 0.000106 | Val Loss: 0.001468
# Hybrid TCN-GCN Epoch 36/50 | Train Loss: 0.000126 | Val Loss: 0.001440
# Hybrid TCN-GCN Epoch 37/50 | Train Loss: 0.000119 | Val Loss: 0.001435
# Hybrid TCN-GCN Epoch 38/50 | Train Loss: 0.000118 | Val Loss: 0.001432
# Hybrid TCN-GCN Epoch 39/50 | Train Loss: 0.000090 | Val Loss: 0.002128
# Hybrid TCN-GCN Epoch 40/50 | Train Loss: 0.000097 | Val Loss: 0.002205
# Hybrid TCN-GCN Epoch 41/50 | Train Loss: 0.000087 | Val Loss: 0.002069
# Hybrid TCN-GCN Epoch 42/50 | Train Loss: 0.000089 | Val Loss: 0.002082
# Hybrid TCN-GCN Epoch 43/50 | Train Loss: 0.000125 | Val Loss: 0.001672
# Hybrid TCN-GCN Epoch 44/50 | Train Loss: 0.000097 | Val Loss: 0.001174
# Hybrid TCN-GCN Epoch 45/50 | Train Loss: 0.000100 | Val Loss: 0.001604
# Hybrid TCN-GCN Epoch 46/50 | Train Loss: 0.000113 | Val Loss: 0.001633
# Hybrid TCN-GCN Epoch 47/50 | Train Loss: 0.000101 | Val Loss: 0.001369
# Hybrid TCN-GCN Epoch 48/50 | Train Loss: 0.000119 | Val Loss: 0.001412
# Hybrid TCN-GCN Epoch 49/50 | Train Loss: 0.000104 | Val Loss: 0.001296
# Hybrid TCN-GCN Epoch 50/50 | Train Loss: 0.000090 | Val Loss: 0.001876
# --- Hybrid TCN-GCN Training Complete ---
#
# Hybrid TCN-GCN Final R²: 0.8190, RMSE: 71.5229, MAE: 52.5327

# %%
# ==============================================================================
# Part 9: PROCEDURAL HYBRID MODEL (GRU + GCN)
# ==============================================================================

print("\n\n" + "=" * 60); print("PART 9: PROCEDURAL HYBRID MODEL (GRU + GCN)"); print("=" * 60)

HYBRID_INPUT_DIM, GRU_HIDDEN_DIM, GCN_HIDDEN_DIM, HYBRID_OUTPUT_DIM = X_train.shape[2], 64, 128, 1
GRU_NUM_LAYERS, HYBRID_DROPOUT = 1, 0.3
HYBRID_EPOCHS, HYBRID_BATCH_SIZE, HYBRID_LR = 50, 32, 0.001

# Define Layers
hybrid_gru_layer = nn.GRU(HYBRID_INPUT_DIM, GRU_HIDDEN_DIM, GRU_NUM_LAYERS, batch_first=True).to(device)
hybrid_gcn1 = nn.Linear(HYBRID_INPUT_DIM, GCN_HIDDEN_DIM).to(device)
hybrid_gcn2 = nn.Linear(GCN_HIDDEN_DIM, GCN_HIDDEN_DIM).to(device)
hybrid_dropout = nn.Dropout(HYBRID_DROPOUT)
hybrid_fc_layer = nn.Linear(GRU_HIDDEN_DIM + GCN_HIDDEN_DIM, HYBRID_OUTPUT_DIM).to(device)

# Optimizer & Loss
hybrid_params = list(hybrid_gru_layer.parameters()) + list(hybrid_gcn1.parameters()) + list(hybrid_gcn2.parameters()) + list(hybrid_fc_layer.parameters())
hybrid_optimizer = torch.optim.Adam(hybrid_params, lr=HYBRID_LR)
hybrid_criterion = nn.MSELoss()
hybrid_train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=HYBRID_BATCH_SIZE, shuffle=True)
loss_history['Hybrid_GRU_GCN'], val_loss_history['Hybrid_GRU_GCN'] = [], []

print("\n--- Starting Hybrid GRU-GCN Model Training ---")
for epoch in range(HYBRID_EPOCHS):
    hybrid_gru_layer.train(); hybrid_gcn1.train(); hybrid_gcn2.train(); hybrid_fc_layer.train(); running_loss = 0.0
    for xb, yb in hybrid_train_loader:
        xb, yb = xb.to(device), yb.to(device)
        # GRU path
        gru_out, _ = hybrid_gru_layer(xb)
        gru_feat = gru_out[:, -1, :]
        # GCN path over time
        gcn_feats = []
        for t in range(xb.size(1)):
            xt = xb[:, t, :]
            xt = torch.matmul(xt, adj_tensor)
            xt = F.relu(hybrid_gcn1(xt))
            xt = F.relu(hybrid_gcn2(xt))
            xt = hybrid_dropout(xt)
            gcn_feats.append(xt.unsqueeze(1))
        gcn_seq = torch.cat(gcn_feats, dim=1)
        gcn_feat = gcn_seq[:, -1, :]
        # Combine and predict
        combined = torch.cat([gru_feat, gcn_feat], dim=1)
        pred = hybrid_fc_layer(combined)
        loss = hybrid_criterion(pred, yb)
        hybrid_optimizer.zero_grad(); loss.backward(); hybrid_optimizer.step(); running_loss += loss.item()
    avg_epoch_loss = running_loss / len(hybrid_train_loader)
    loss_history['Hybrid_GRU_GCN'].append(avg_epoch_loss)

    # Validation
    with torch.no_grad():
        val_gru, _ = hybrid_gru_layer(X_val.to(device))
        val_gru_feat = val_gru[:, -1, :]
        val_gcn_feats = []
        for t in range(X_val.size(1)):
            xt = X_val[:, t, :].to(device)
            xt = torch.matmul(xt, adj_tensor)
            xt = F.relu(hybrid_gcn1(xt))
            xt = F.relu(hybrid_gcn2(xt))
            xt = hybrid_dropout(xt)
            val_gcn_feats.append(xt.unsqueeze(1))
        val_gcn_seq = torch.cat(val_gcn_feats, dim=1)
        val_gcn_feat = val_gcn_seq[:, -1, :]
        val_combined = torch.cat([val_gru_feat, val_gcn_feat], dim=1)
        val_pred = hybrid_fc_layer(val_combined)
        val_loss = hybrid_criterion(val_pred, Y_val.to(device))
        val_loss_history['Hybrid_GRU_GCN'].append(val_loss.item())

    print(f"Hybrid GRU-GCN Epoch {epoch+1:2d}/{HYBRID_EPOCHS} | Train Loss: {avg_epoch_loss:.6f} | Val Loss: {val_loss.item():.6f}")

print("--- Hybrid GRU-GCN Training Complete ---")

# Evaluation on test
with torch.no_grad():
    test_gru, _ = hybrid_gru_layer(X_test.to(device))
    test_gru_feat = test_gru[:, -1, :]
    test_gcn_feats = []
    for t in range(X_test.size(1)):
        xt = X_test[:, t, :].to(device)
        xt = torch.matmul(xt, adj_tensor)
        xt = F.relu(hybrid_gcn1(xt))
        xt = F.relu(hybrid_gcn2(xt))
        xt = hybrid_dropout(xt)
        test_gcn_feats.append(xt.unsqueeze(1))
    test_gcn_seq = torch.cat(test_gcn_feats, dim=1)
    test_gcn_feat = test_gcn_seq[:, -1, :]
    test_combined = torch.cat([test_gru_feat, test_gcn_feat], dim=1)
    hybrid_test_pred = hybrid_fc_layer(test_combined)

    hybrid_preds_rescaled = target_scaler.inverse_transform(hybrid_test_pred.cpu().numpy())
    hybrid_true_rescaled = target_scaler.inverse_transform(Y_test.cpu().numpy())

hybrid_r2 = r2_score(hybrid_true_rescaled, hybrid_preds_rescaled)
hybrid_rmse = np.sqrt(mean_squared_error(hybrid_true_rescaled, hybrid_preds_rescaled))
hybrid_mae = mean_absolute_error(hybrid_true_rescaled, hybrid_preds_rescaled)

r2_scores['Hybrid_GRU_GCN'] = hybrid_r2
rmse_scores['Hybrid_GRU_GCN'] = hybrid_rmse
mae_scores['Hybrid_GRU_GCN'] = hybrid_mae

print(f"\nHybrid GRU-GCN Final R²: {hybrid_r2:.4f}, RMSE: {hybrid_rmse:.4f}, MAE: {hybrid_mae:.4f}")
plt.figure(figsize=(12, 5))
plt.plot(hybrid_true_rescaled[:200], label='Actual')
plt.plot(hybrid_preds_rescaled[:200], label='Predicted')
plt.title('Hybrid GRU-GCN')
plt.xlabel("Days")
plt.ylabel("Total")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ============================================================
# PART 9: PROCEDURAL HYBRID MODEL (GRU + GCN)
# ============================================================
#
# --- Starting Hybrid GRU-GCN Model Training ---
# Hybrid GRU-GCN Epoch  1/50 | Train Loss: 0.005253 | Val Loss: 0.000553
# Hybrid GRU-GCN Epoch  2/50 | Train Loss: 0.000552 | Val Loss: 0.000219
# Hybrid GRU-GCN Epoch  3/50 | Train Loss: 0.000423 | Val Loss: 0.000260
# Hybrid GRU-GCN Epoch  4/50 | Train Loss: 0.000371 | Val Loss: 0.000742
# Hybrid GRU-GCN Epoch  5/50 | Train Loss: 0.000328 | Val Loss: 0.000260
# Hybrid GRU-GCN Epoch  6/50 | Train Loss: 0.000312 | Val Loss: 0.000852
# Hybrid GRU-GCN Epoch  7/50 | Train Loss: 0.000274 | Val Loss: 0.000554
# Hybrid GRU-GCN Epoch  8/50 | Train Loss: 0.000258 | Val Loss: 0.000796
# Hybrid GRU-GCN Epoch  9/50 | Train Loss: 0.000248 | Val Loss: 0.000868
# Hybrid GRU-GCN Epoch 10/50 | Train Loss: 0.000231 | Val Loss: 0.000250
# Hybrid GRU-GCN Epoch 11/50 | Train Loss: 0.000215 | Val Loss: 0.000574
# Hybrid GRU-GCN Epoch 12/50 | Train Loss: 0.000197 | Val Loss: 0.000450
# Hybrid GRU-GCN Epoch 13/50 | Train Loss: 0.000163 | Val Loss: 0.000681
# Hybrid GRU-GCN Epoch 14/50 | Train Loss: 0.000164 | Val Loss: 0.000509
# Hybrid GRU-GCN Epoch 15/50 | Train Loss: 0.000132 | Val Loss: 0.000549
# Hybrid GRU-GCN Epoch 16/50 | Train Loss: 0.000121 | Val Loss: 0.000193
# Hybrid GRU-GCN Epoch 17/50 | Train Loss: 0.000114 | Val Loss: 0.000443
# Hybrid GRU-GCN Epoch 18/50 | Train Loss: 0.000116 | Val Loss: 0.000664
# Hybrid GRU-GCN Epoch 19/50 | Train Loss: 0.000094 | Val Loss: 0.000506
# Hybrid GRU-GCN Epoch 20/50 | Train Loss: 0.000078 | Val Loss: 0.000302
# Hybrid GRU-GCN Epoch 21/50 | Train Loss: 0.000076 | Val Loss: 0.000608
# Hybrid GRU-GCN Epoch 22/50 | Train Loss: 0.000092 | Val Loss: 0.000722
# Hybrid GRU-GCN Epoch 23/50 | Train Loss: 0.000070 | Val Loss: 0.000044
# Hybrid GRU-GCN Epoch 24/50 | Train Loss: 0.000094 | Val Loss: 0.000335
# Hybrid GRU-GCN Epoch 25/50 | Train Loss: 0.000059 | Val Loss: 0.000405
# Hybrid GRU-GCN Epoch 26/50 | Train Loss: 0.000066 | Val Loss: 0.000940
# Hybrid GRU-GCN Epoch 27/50 | Train Loss: 0.000064 | Val Loss: 0.000259
# Hybrid GRU-GCN Epoch 28/50 | Train Loss: 0.000051 | Val Loss: 0.000584
# Hybrid GRU-GCN Epoch 29/50 | Train Loss: 0.000114 | Val Loss: 0.000687
# Hybrid GRU-GCN Epoch 30/50 | Train Loss: 0.000067 | Val Loss: 0.000096
# Hybrid GRU-GCN Epoch 31/50 | Train Loss: 0.000137 | Val Loss: 0.000520
# Hybrid GRU-GCN Epoch 32/50 | Train Loss: 0.000078 | Val Loss: 0.000206
# Hybrid GRU-GCN Epoch 33/50 | Train Loss: 0.000073 | Val Loss: 0.000711
# Hybrid GRU-GCN Epoch 34/50 | Train Loss: 0.000061 | Val Loss: 0.001331
# Hybrid GRU-GCN Epoch 35/50 | Train Loss: 0.000057 | Val Loss: 0.000278
# Hybrid GRU-GCN Epoch 36/50 | Train Loss: 0.000054 | Val Loss: 0.000058
# Hybrid GRU-GCN Epoch 37/50 | Train Loss: 0.000060 | Val Loss: 0.000132
# Hybrid GRU-GCN Epoch 38/50 | Train Loss: 0.000043 | Val Loss: 0.001613
# Hybrid GRU-GCN Epoch 39/50 | Train Loss: 0.000041 | Val Loss: 0.000354
# Hybrid GRU-GCN Epoch 40/50 | Train Loss: 0.000047 | Val Loss: 0.001132
# Hybrid GRU-GCN Epoch 41/50 | Train Loss: 0.000040 | Val Loss: 0.000444
# Hybrid GRU-GCN Epoch 42/50 | Train Loss: 0.000023 | Val Loss: 0.001965
# Hybrid GRU-GCN Epoch 43/50 | Train Loss: 0.000051 | Val Loss: 0.000813
# Hybrid GRU-GCN Epoch 44/50 | Train Loss: 0.000051 | Val Loss: 0.001031
# Hybrid GRU-GCN Epoch 45/50 | Train Loss: 0.000038 | Val Loss: 0.000575
# Hybrid GRU-GCN Epoch 46/50 | Train Loss: 0.000061 | Val Loss: 0.001275
# Hybrid GRU-GCN Epoch 47/50 | Train Loss: 0.000037 | Val Loss: 0.000882
# Hybrid GRU-GCN Epoch 48/50 | Train Loss: 0.000039 | Val Loss: 0.000876
# Hybrid GRU-GCN Epoch 49/50 | Train Loss: 0.000023 | Val Loss: 0.001703
# Hybrid GRU-GCN Epoch 50/50 | Train Loss: 0.000037 | Val Loss: 0.000462
# --- Hybrid GRU-GCN Training Complete ---
#
# Hybrid GRU-GCN Final R²: 0.9806, RMSE: 23.4235, MAE: 11.3695

# %%
# ==============================================================================
# Part 10: Final Metrics Comparison (Including Hybrids)
# ==============================================================================

print("\n\n" + "=" * 60)
print("📊 Final Metrics Comparison (Including Hybrid Models) 📊")
print("=" * 60)
print(f"{'Model':<20} | {'R² Score':>10} | {'RMSE':>10} | {'MAE':>10}")
print("-" * 60)

model_order = [
    'TCN', 'LSTM', 'BiLSTM', 'GRU', 'BiGRU', 'GCN',
    'Hybrid_TCN_GCN',               # TCN-GCN
    'Hybrid_GRU_GCN'        # GRU-GCN
]

for model_name in model_order:
    r2 = r2_scores.get(model_name, float('nan'))
    rmse = rmse_scores.get(model_name, float('nan'))
    mae = mae_scores.get(model_name, float('nan'))
    print(f"{model_name:<20} | {r2:>10.4f} | {rmse:>10.4f} | {mae:>10.4f}")

print("=" * 60)
# Out:
# ============================================================
# 📊 Final Metrics Comparison (Including Hybrid Models) 📊
# ============================================================
# Model                |   R² Score |       RMSE |        MAE
# ------------------------------------------------------------
# TCN                  |     0.9509 |    37.2363 |    18.8410
# LSTM                 |     0.9450 |    39.4193 |    19.2940
# BiLSTM               |     0.9050 |    51.8258 |    23.7593
# GRU                  |     0.9698 |    29.2377 |    12.7870
# BiGRU                |     0.9663 |    30.8577 |    15.3083
# GCN                  |     0.7905 |    76.9539 |    56.2883
# Hybrid_TCN_GCN       |     0.8190 |    71.5229 |    52.5327
# Hybrid_GRU_GCN       |     0.9806 |    23.4235 |    11.3695
# ============================================================

# %%
# ==============================================================================
# Part 10: Comparative Training Loss Graph
# ==============================================================================
print("\n\n" + "=" * 60); print("PART 10: COMPARATIVE TRAINING LOSS CURVES"); print("=" * 60)
plt.figure(figsize=(14, 8))

# Extend model order to include hybrid models explicitly
plot_models = model_order + ['Hybrid_TCN_GCN', 'Hybrid_GRU_GCN']

for model_name, losses in loss_history.items():
    if model_name in plot_models:
        plt.plot(range(1, len(losses) + 1), losses, label=f'{model_name} Training Loss', marker='o', linestyle='--')

plt.title('Training Loss Comparison Across Models', fontsize=16)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Average Training Loss (Log Scale)', fontsize=12)
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xticks(range(1, max([len(l) for l in loss_history.values() if len(l) > 0]) + 1))
plt.yscale('log')
plt.tight_layout()
print("Displaying the comparative training loss graph. Close the plot to continue.")
plt.show()
# Out:
# ============================================================
# PART 10: COMPARATIVE TRAINING LOSS CURVES
# ============================================================
# Displaying the comparative training loss graph. Close the plot to continue.

# %%
# ==============================================================================
# Part 11: Per-Model Training vs. Validation Loss Graphs
# ==============================================================================
print("\n\n" + "=" * 60)
print("PART 11: PER-MODEL TRAINING VS. VALIDATION LOSS")
print("=" * 60)

# Extend model order to include hybrid models with correct keys
plot_models = model_order 

for model_name in plot_models:
    if model_name in loss_history and model_name in val_loss_history:
        plt.figure(figsize=(10, 5))
        plt.plot(loss_history[model_name], label=f"{model_name} Training Loss")
        plt.plot(val_loss_history[model_name], label=f"{model_name} Validation Loss", linestyle='--')
        plt.title(f"{model_name}: Training and Validation Loss")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.grid(True)
        plt.show()

print("\nAll analysis and plotting complete.")
# Out:
# ============================================================
# PART 11: PER-MODEL TRAINING VS. VALIDATION LOSS
# ============================================================
# All analysis and plotting complete.
